# %%
# Q.[1] : Write a Python Program to Find LCM?

a = int(input("Enter first number: "))
b = int(input("Enter secoend number: "))

maxnum = max(a,b)

while True:
    if (maxnum % a == 0 and maxnum % b == 0):
        break
    maxnum = maxnum + 1
print(f"The LCM of {a} and {b} is: {maxnum}")
# Out:
# Enter first number: 20
# Enter secoend number: 24
# The LCM of 20 and 24 is: 120

# %%
# Q.[2] : Write a Python Program to Find HCF?
num1 = int(input("Enter first number: "))
num2 = int(input("Enter secoend number: "))

if num2 > num1 :
    mn = num1
else:
    mn = num2
for i in range(1,mn + 1):
    if num1 % i == 0 and num2 % i == 0:
        hcf = i
print(f"The HCF of {num1} and {num2} is: {hcf}")
# Out:
# Enter first number: 28
# Enter secoend number: 32
# The HCF of 28 and 32 is: 4

# %%
# Q.[3] : Write a Python Program to Convert Decimal to Binary, Octal and Hexadecimal?

dec = 20
print(f"{bin(dec)} in binary")

oct = 24
print(f"{hex(oct)} in hexadecimal")
# Out:
# 0b10100 in binary
# 0x18 in hexadecimal

# %%
# Q.[4] : Write a Python Program To Find ASCII value of a character?

D = "d"
print(f"The ASCII Value of {D} is: {ord(D)}")
# Out:
# The ASCII Value of d is: 100

# %%
# Q.[5] : Write a Python Program to Make a Simple Calculator with 4 basic mathematical operations?

def add(a,b):
    return a + b

def subtract(a,b):
    return a - b

def multiply(a,b):
    return a * b

def divide(a,b):
    return a / b

print("select operation")
print("a.add")
print("b.subtract")
print("c.multiply")
print("d.divide")

choice = input("Enter your choice(a/b/c/d): ")

num1 = int(input("Enter first number: "))
num2 = int(input("enter secoend number: "))

if choice == "a":
    print(f"{num1} + {num2} = {add(num1,num2)}")
    
elif choice =="b":
    print(f"{num1} - {num2} = {subtract(num1,num2)}")
    
elif choice == "c":
    print(f"{num1} * {num2} = {multiply(num1,num2)}")
    
elif choice == "d":
    print(f"{num1} / {num2} = {divide(num1,num2)}")
    
else:
    print("This is an invalid input")
# Out:
# select operation
# a.add
# b.subtract
# c.multiply
# d.divide
# Enter your choice(a/b/c/d): a
# Enter first number: 20
# enter secoend number: 19
# 20 + 19 = 39

# %%
def add(a,b):
    return a + b

def subtract(a,b):
    return a - b

def multiply(a,b):
    return a * b

def divide(a,b):
    return a / b

print("select operation")
print("a.add")
print("b.subtract")
print("c.multiply")
print("d.divide")

choice = input("Enter your choice(a/b/c/d): ")

num1 = int(input("Enter first number: "))
num2 = int(input("enter secoend number: "))

if choice == "a":
    print(f"{num1} + {num2} = {add(num1,num2)}")
    
elif choice =="b":
    print(f"{num1} - {num2} = {subtract(num1,num2)}")
    
elif choice == "c":
    print(f"{num1} * {num2} = {multiply(num1,num2)}")
    
elif choice == "d":
    print(f"{num1} / {num2} = {divide(num1,num2)}")
    
else:
    print("This is an invalid input")
# Out:
# select operation
# a.add
# b.subtract
# c.multiply
# d.divide
# Enter your choice(a/b/c/d): d
# Enter first number: 20
# enter secoend number: 10
# 20 / 10 = 2.0
